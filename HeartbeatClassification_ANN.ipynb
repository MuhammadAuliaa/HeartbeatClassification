# %%
import os
import wave
import numpy as np
import pandas as pd
import librosa
import matplotlib.pyplot as plt
import scipy.signal as signal
from scipy.signal import butter, filtfilt, lfilter
import warnings
warnings.filterwarnings('ignore')
import numpy as np
from scipy.signal import butter, lfilter
import seaborn as sns
from sklearn.metrics import confusion_matrix, classification_report, accuracy_score

# %% [markdown]
# ## Import Data

# %%
def load_audio_from_folder(folder_path, label):
    audio_data = []
    
    for filename in os.listdir(folder_path):
        if filename.endswith('.wav'): 
            full_path = os.path.join(folder_path, filename)
            try:
                signal, sr = librosa.load(full_path, sr=None)  # sr=None untuk mempertahankan frekuensi asli
                duration = len(signal) / sr
                audio_data.append({
                    'filename': full_path,
                    'signal': signal,
                    'sampling_rate': sr,
                    'duration': duration,
                    'label': label  # Menambahkan label untuk setiap kategori
                })
            except Exception as e:
                print(f"Error reading {full_path}: {e}")

    return audio_data

artifact_path = 'Heartbeat_Sound/artifact'
artifact_audio = load_audio_from_folder(artifact_path, 'artifact')
df_artifact = pd.DataFrame(artifact_audio)

extrahls_path = 'Heartbeat_Sound/extrahls'
extrahls_audio = load_audio_from_folder(extrahls_path, 'extrahls')
df_extrahls = pd.DataFrame(extrahls_audio)

extrastole_path = 'Heartbeat_Sound/extrastole'
extrastole_audio = load_audio_from_folder(extrastole_path, 'extrastole')
df_extrastole = pd.DataFrame(extrastole_audio)

murmur_path = 'Heartbeat_Sound/murmur'
murmur_audio = load_audio_from_folder(murmur_path, 'murmur')
df_murmur = pd.DataFrame(murmur_audio)

normal_path = 'Heartbeat_Sound/normal'
normal_audio = load_audio_from_folder(normal_path, 'normal')
df_normal = pd.DataFrame(normal_audio)

df = pd.concat([df_artifact,df_murmur, df_normal, df_extrastole, df_extrahls], ignore_index=True)

# %%
df['label'].value_counts()
# Out:
# label
# normal        351
# murmur        129
# extrastole     46
# artifact       40
# extrahls       19
# Name: count, dtype: int64

# %% [markdown]
# ## Preprocessing

# %%
df
# Out:
#                                               filename  \
# 0    Heartbeat_Sound/artifact\artifact__20101217201...
# 1    Heartbeat_Sound/artifact\artifact__20110504091...
# 2    Heartbeat_Sound/artifact\artifact__20110504195...
# 3    Heartbeat_Sound/artifact\artifact__20110505101...
# 4    Heartbeat_Sound/artifact\artifact__20110506010...
# ..                                                 ...
# 580  Heartbeat_Sound/extrahls\extrahls__20110320021...
# 581  Heartbeat_Sound/extrahls\extrahls__20110402135...
# 582  Heartbeat_Sound/extrahls\extrahls__20110414011...
# 583  Heartbeat_Sound/extrahls\extrahls__20110427045...
# 584  Heartbeat_Sound/extrahls\extrahls__20110427045...
#
#                                                 signal  sampling_rate  \
# 0    [3.0517578e-05, -9.1552734e-05, -3.0517578e-05...          44100
# 1    [-6.1035156e-05, 9.1552734e-05, -0.00012207031...          44100
# 2    [0.00018310547, -0.00012207031, -0.0002746582,...          44100
# 3    [-0.0025939941, -0.0060424805, -0.0065307617, ...          44100
# 4    [0.0016174316, -0.0010681152, 0.0014343262, 0....          44100
# ..                                                 ...            ...
# 580  [0.010040283, 0.009857178, 0.010345459, 0.0101...          44100
# 581  [-0.00079345703, -0.00088500977, -0.0010681152...          44100
# 582  [0.00030517578, -3.0517578e-05, -0.00012207031...          44100
# 583  [-0.03036499, -0.028900146, -0.028198242, -0.0...          44100
# 584  [0.07116699, 0.071136475, 0.07067871, 0.070526...          44100
#
#      duration     label
# 0    9.000000  artifact
# 1    9.000000  artifact
# 2    9.000000  artifact
# 3    9.000000  artifact
# 4    9.000000  artifact
# ..        ...       ...
# 580  9.000000  extrahls
# 581  0.936372  extrahls
# 582  1.947392  extrahls
# 583  3.235397  extrahls
# 584  1.645238  extrahls
#
# [585 rows x 5 columns]

# %%
def normalize_audio(signal):
    """Normalizes the audio signal to the range [-1, 1]."""
    return signal / np.max(np.abs(signal))

def band_pass_filter(signal, lowcut, highcut, fs, order=5):
    """Applies a band-pass filter to the audio signal."""
    nyquist = 0.5 * fs
    low = lowcut / nyquist
    high = highcut / nyquist
    b, a = butter(order, [low, high], btype='band')
    return lfilter(b, a, signal)

def clip_or_pad(signal, target_samples):
    """Clips or pads the audio signal to the target length."""
    if len(signal) < target_samples:
        signal = np.pad(signal, (0, target_samples - len(signal)), 'constant')
    else:
        signal = signal[:target_samples]
    return signal  # Return the processed signal

def preprocess(row, target_duration):
    """Processes a single row of the DataFrame."""
    signal = row['signal']
    sr = row['sampling_rate']
    target_samples = int(target_duration * sr)
    
    normalized_signal = normalize_audio(signal)
    
    processed_signal = clip_or_pad(normalized_signal, target_samples)
    
    # Adjust the band-pass filter frequencies according to the characteristics of your data
    filtered_signal = band_pass_filter(processed_signal, lowcut=100, highcut=1500, fs=sr)
    
    return filtered_signal

# Define target duration for padding/clipping
target_duration = 6  # in seconds
df['processed_signal'] = df.apply(lambda row: preprocess(row, target_duration), axis=1)

# %%
def plot_signal(signal, fs):
    """Plot the audio signal."""
    time = np.arange(len(signal)) / fs
    plt.figure(figsize=(10, 5))
    plt.plot(time, signal)
    plt.title('Audio Signal')
    plt.xlabel('Time (seconds)')
    plt.ylabel('Amplitude')
    plt.grid()
    plt.show()

fs = 4000  # Sampling rate
plot_signal(df['signal'][100], fs)
plot_signal(df['processed_signal'][100], fs)

# %% [markdown]
# ## Feature Extraction

# %%
def extract_features(signal, sr):
    # Menghitung rata-rata interval detak
    intervals = np.diff(np.where(signal > 0)[0]) / sr
    mean_interval = np.mean(intervals) if len(intervals) > 0 else np.nan

    # Menghitung HRV (SDNN dan RMSSD)
    sdnn = np.std(intervals) if len(intervals) > 0 else np.nan
    rmssd = np.sqrt(np.mean(np.square(np.diff(intervals)))) if len(intervals) > 1 else np.nan

    # Menghitung FFT dan puncak frekuensi
    freqs = np.fft.rfftfreq(len(signal), d=1/sr)
    fft_values = np.abs(np.fft.rfft(signal))
    peak_freq = freqs[np.argmax(fft_values)] if len(fft_values) > 0 else np.nan

    # Menghitung energi
    energy = np.sum(signal**2)

    # Menghitung MFCC
    mfccs = librosa.feature.mfcc(y=signal, sr=sr, n_mfcc=13)
    mfcc_mean = np.mean(mfccs, axis=1)

    # Zero-crossing rate
    zero_crossings = librosa.feature.zero_crossing_rate(signal)[0]
    zero_crossing_rate = np.mean(zero_crossings)

    # Spectral centroid
    spectral_centroid = librosa.feature.spectral_centroid(y=signal, sr=sr)[0]
    spectral_centroid_mean = np.mean(spectral_centroid)

    # Spectral bandwidth
    spectral_bandwidth = librosa.feature.spectral_bandwidth(y=signal, sr=sr)[0]
    spectral_bandwidth_mean = np.mean(spectral_bandwidth)

    # Chroma features
    chroma = librosa.feature.chroma_stft(y=signal, sr=sr)
    chroma_mean = np.mean(chroma, axis=1)

    # RMS Energy
    rms = librosa.feature.rms(y=signal)[0]
    rms_mean = np.mean(rms)

    return {
        'mean_interval': mean_interval,
        'sdnn': sdnn,
        'rmssd': rmssd,
        'peak_freq': peak_freq,
        'energy': energy,
        'mfcc_mean': mfcc_mean,
        'zero_crossing_rate': zero_crossing_rate,
        'spectral_centroid_mean': spectral_centroid_mean,
        'spectral_bandwidth_mean': spectral_bandwidth_mean,
        'chroma_mean': chroma_mean,
        'rms_mean': rms_mean
    }


def process_feature_extract(df):
    all_features = []

    for index, row in df.iterrows():
        signal = row['processed_signal']
        sr = row['sampling_rate']
        
        features = extract_features(signal, sr)
        features['filename'] = row['filename']
        
        all_features.append(features)

    return pd.DataFrame(all_features)

features_df = process_feature_extract(df)

features_df.head()
# Out:
#    mean_interval      sdnn     rmssd   peak_freq      energy  \
# 0       0.000045  0.000170  0.000243  181.666667  145.288924
# 1       0.000045  0.000129  0.000185  211.166667  148.151620
# 2       0.000046  0.000132  0.000189  463.666667  177.689774
# 3       0.000045  0.000172  0.000246  467.500000   73.003435
# 4       0.000045  0.000167  0.000238  173.666667  471.737747
#
#                                            mfcc_mean  zero_crossing_rate  \
# 0  [-576.5830033241881, 42.4807548287202, 22.0072...            0.030981
# 1  [-591.0930282083615, 72.61962264099854, 10.406...            0.041962
# 2  [-472.5488412621986, 233.50278592498535, 23.65...            0.039681
# 3  [-496.0363088234935, 222.8071052952423, 57.081...            0.022709
# 4  [-422.2670699562918, 165.601640650228, 51.4227...            0.027088
#
#    spectral_centroid_mean  spectral_bandwidth_mean  \
# 0              785.068608               555.881113
# 1              958.109446               622.322985
# 2              922.469841               553.807820
# 3              655.737940               464.209141
# 4              718.736199               507.577118
#
#                                          chroma_mean  rms_mean  \
# 0  [0.57921060788811, 0.5494573176662759, 0.56173...  0.004324
# 1  [0.5942578927973968, 0.6090658466992702, 0.616...  0.009696
# 2  [0.58985941156076, 0.6718455575767825, 0.60735...  0.016369
# 3  [0.48849284425059963, 0.45427845884236695, 0.4...  0.013869
# 4  [0.5678437042125806, 0.6021268103545843, 0.573...  0.020556
#
#                                             filename
# 0  Heartbeat_Sound/artifact\artifact__20101217201...
# 1  Heartbeat_Sound/artifact\artifact__20110504091...
# 2  Heartbeat_Sound/artifact\artifact__20110504195...
# 3  Heartbeat_Sound/artifact\artifact__20110505101...
# 4  Heartbeat_Sound/artifact\artifact__20110506010...

# %% [markdown]
# ## Modeling (ANN)

# %%
features_df
# Out:
#      mean_interval      sdnn     rmssd   peak_freq       energy  \
# 0         0.000045  0.000170  0.000243  181.666667   145.288924
# 1         0.000045  0.000129  0.000185  211.166667   148.151620
# 2         0.000046  0.000132  0.000189  463.666667   177.689774
# 3         0.000045  0.000172  0.000246  467.500000    73.003435
# 4         0.000045  0.000167  0.000238  173.666667   471.737747
# ..             ...       ...       ...         ...          ...
# 580       0.000045  0.000251  0.000356  157.666667   571.346081
# 581       0.000045  0.000346  0.000490  140.666667   469.081364
# 582       0.000046  0.000313  0.000444  134.500000   437.619915
# 583       0.000045  0.000297  0.000422  139.500000  1626.122994
# 584       0.000045  0.000328  0.000465  146.833333  1020.702330
#
#                                              mfcc_mean  zero_crossing_rate  \
# 0    [-576.5830033241881, 42.4807548287202, 22.0072...            0.030981
# 1    [-591.0930282083615, 72.61962264099854, 10.406...            0.041962
# 2    [-472.5488412621986, 233.50278592498535, 23.65...            0.039681
# 3    [-496.0363088234935, 222.8071052952423, 57.081...            0.022709
# 4    [-422.2670699562918, 165.601640650228, 51.4227...            0.027088
# ..                                                 ...                 ...
# 580  [-464.654203839591, 147.97844904086145, 83.096...            0.010387
# 581  [-525.7345286312446, 29.562147165581923, 12.51...            0.001953
# 582  [-498.8124558770372, 43.070962223648756, 18.85...            0.006469
# 583  [-453.421365235846, 82.63927915462787, 45.0337...            0.004742
# 584  [-487.48794482567445, 42.742323654218275, 23.3...            0.002414
#
#      spectral_centroid_mean  spectral_bandwidth_mean  \
# 0                785.068608               555.881113
# 1                958.109446               622.322985
# 2                922.469841               553.807820
# 3                655.737940               464.209141
# 4                718.736199               507.577118
# ..                      ...                      ...
# 580              352.039087               331.003965
# 581              134.915686               105.125088
# 582              253.138227               202.071390
# 583              220.749034               201.202505
# 584              158.560315               127.061195
#
#                                            chroma_mean  rms_mean  \
# 0    [0.57921060788811, 0.5494573176662759, 0.56173...  0.004324
# 1    [0.5942578927973968, 0.6090658466992702, 0.616...  0.009696
# 2    [0.58985941156076, 0.6718455575767825, 0.60735...  0.016369
# 3    [0.48849284425059963, 0.45427845884236695, 0.4...  0.013869
# 4    [0.5678437042125806, 0.6021268103545843, 0.573...  0.020556
# ..                                                 ...       ...
# 580  [0.5107219814775679, 0.5073032661892927, 0.575...  0.030011
# 581  [0.30482202364203453, 0.26155219623483267, 0.2...  0.012792
# 582  [0.4311472972659982, 0.3855219863644065, 0.363...  0.011572
# 583  [0.5123252384168187, 0.47695488013742965, 0.48...  0.042396
# 584  [0.3474714584043968, 0.3157657915489688, 0.323...  0.024088
#
#                                               filename
# 0    Heartbeat_Sound/artifact\artifact__20101217201...
# 1    Heartbeat_Sound/artifact\artifact__20110504091...
# 2    Heartbeat_Sound/artifact\artifact__20110504195...
# 3    Heartbeat_Sound/artifact\artifact__20110505101...
# 4    Heartbeat_Sound/artifact\artifact__20110506010...
# ..                                                 ...
# 580  Heartbeat_Sound/extrahls\extrahls__20110320021...
# 581  Heartbeat_Sound/extrahls\extrahls__20110402135...
# 582  Heartbeat_Sound/extrahls\extrahls__20110414011...
# 583  Heartbeat_Sound/extrahls\extrahls__20110427045...
# 584  Heartbeat_Sound/extrahls\extrahls__20110427045...
#
# [585 rows x 12 columns]

# %%
import numpy as np
import pandas as pd
import tensorflow as tf
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, BatchNormalization

# Assume you already loaded the dataset as 'features_df' and added 'label' column
# And you already did this preprocessing:
mfcc_flattened = np.array(features_df['mfcc_mean'].tolist())  # shape: (n_samples, 13)
chroma_flattened = np.array(features_df['chroma_mean'].tolist())  # shape: (n_samples, 12)

# Concatenate all numerical features
X = np.hstack((
    features_df[['mean_interval', 'sdnn', 'rmssd', 'peak_freq', 'energy',
                 'zero_crossing_rate', 'spectral_centroid_mean',
                 'spectral_bandwidth_mean', 'rms_mean']].values,
    mfcc_flattened, chroma_flattened
))

# %%
# Encode the target
label_encoder = LabelEncoder()
y = label_encoder.fit_transform(df['label'])  # Ensure 'label' column is present

# Train-validation-test split
x_train, x_test, y_train, y_test = train_test_split(X, y, train_size=0.8, random_state=42, stratify=y)
x_train, x_val, y_train, y_val = train_test_split(x_train, y_train, train_size=0.8, random_state=42, stratify=y_train)

# One-hot encoding for classification
num_classes = len(np.unique(y))
y_train = tf.keras.utils.to_categorical(y_train, num_classes)
y_val = tf.keras.utils.to_categorical(y_val, num_classes)
y_test = tf.keras.utils.to_categorical(y_test, num_classes)

# %%
x_train
# Out:
# array([[5.00897779e-04, 9.69384910e-04, 1.40724967e-03, ...,
#         4.67387520e-01, 3.42947927e-01, 2.96769017e-01],
#        [5.04691181e-04, 7.78384185e-04, 1.14716024e-03, ...,
#         6.69509077e-01, 6.81238269e-01, 6.56645940e-01],
#        [5.00981293e-04, 9.75182739e-04, 1.41791464e-03, ...,
#         7.07728099e-01, 4.72132137e-01, 3.67788957e-01],
#        ...,
#        [5.01987448e-04, 9.30504218e-04, 1.35110215e-03, ...,
#         6.58463070e-01, 5.08253426e-01, 4.46123197e-01],
#        [4.60771282e-05, 3.02649222e-04, 4.29289842e-04, ...,
#         6.11899299e-01, 6.11101399e-01, 6.29493240e-01],
#        [4.56050122e-05, 2.14111563e-04, 3.04420913e-04, ...,
#         6.55558222e-01, 6.62197267e-01, 6.92127160e-01]])

# %%
model = Sequential([
    Dense(128, input_shape=(X.shape[1],), activation='relu'),
    BatchNormalization(),
    Dropout(0.3),
    
    Dense(64, activation='relu'),
    BatchNormalization(),
    Dropout(0.3),

    Dense(32, activation='relu'),
    Dense(num_classes, activation='softmax')  # Output layer for multi-class classification
])

model.compile(optimizer='adam',
              loss='categorical_crossentropy',
              metrics=['accuracy'])

history = model.fit(x_train, y_train,
                    epochs=100,
                    batch_size=32,
                    validation_data=(x_val, y_val),
                    verbose=1)
# Out:
# Epoch 1/100
# 12/12 [==============================] - 1s 18ms/step - loss: 1.8183 - accuracy: 0.3048 - val_loss: 2.0694 - val_accuracy: 0.1702
# Epoch 2/100
# 12/12 [==============================] - 0s 6ms/step - loss: 1.4688 - accuracy: 0.4679 - val_loss: 1.5576 - val_accuracy: 0.5426
# Epoch 3/100
# 12/12 [==============================] - 0s 6ms/step - loss: 1.2429 - accuracy: 0.5561 - val_loss: 1.4204 - val_accuracy: 0.5851
# Epoch 4/100
# 12/12 [==============================] - 0s 6ms/step - loss: 1.1765 - accuracy: 0.5856 - val_loss: 1.3298 - val_accuracy: 0.5957
# Epoch 5/100
# 12/12 [==============================] - 0s 5ms/step - loss: 1.0346 - accuracy: 0.6417 - val_loss: 1.2368 - val_accuracy: 0.6383
# Epoch 6/100
# 12/12 [==============================] - 0s 6ms/step - loss: 1.0533 - accuracy: 0.6337 - val_loss: 1.1904 - val_accuracy: 0.6277
# Epoch 7/100
# 12/12 [==============================] - 0s 6ms/step - loss: 1.0270 - accuracy: 0.6390 - val_loss: 1.1268 - val_accuracy: 0.6489
# Epoch 8/100
# 12/12 [==============================] - 0s 6ms/step - loss: 0.9982 - accuracy: 0.6524 - val_loss: 1.0771 - val_accuracy: 0.6383
# Epoch 9/100
# 12/12 [==============================] - 0s 6ms/step - loss: 0.9560 - accuracy: 0.6497 - val_loss: 1.0409 - val_accuracy: 0.6489
# Epoch 10/100
# 12/12 [==============================] - 0s 5ms/step - loss: 0.9844 - accuracy: 0.6230 - val_loss: 1.0016 - val_accuracy: 0.6489
# Epoch 11/100
# 12/12 [==============================] - 0s 6ms/step - loss: 0.9501 - accuracy: 0.6444 - val_loss: 0.9787 - val_accuracy: 0.6277
# Epoch 12/100
# 12/12 [==============================] - 0s 6ms/step - loss: 0.9002 - accuracy: 0.6631 - val_loss: 0.9721 - val_accuracy: 0.6170
# Epoch 13/100
# 12/12 [==============================] - 0s 6ms/step - loss: 0.9042 - accuracy: 0.6390 - val_loss: 0.9592 - val_accuracy: 0.6489
# Epoch 14/100
# 12/12 [==============================] - 0s 6ms/step - loss: 0.9116 - accuracy: 0.6551 - val_loss: 0.9376 - val_accuracy: 0.6170
# Epoch 15/100
# 12/12 [==============================] - 0s 6ms/step - loss: 0.8795 - accuracy: 0.6898 - val_loss: 0.9163 - val_accuracy: 0.6277
# Epoch 16/100
# 12/12 [==============================] - 0s 6ms/step - loss: 0.8456 - accuracy: 0.6765 - val_loss: 0.9037 - val_accuracy: 0.6383
# Epoch 17/100
# 12/12 [==============================] - 0s 9ms/step - loss: 0.8362 - accuracy: 0.6791 - val_loss: 0.8966 - val_accuracy: 0.6489
# Epoch 18/100
# 12/12 [==============================] - 0s 6ms/step - loss: 0.8310 - accuracy: 0.6818 - val_loss: 0.8863 - val_accuracy: 0.6702
# Epoch 19/100
# 12/12 [==============================] - 0s 6ms/step - loss: 0.8897 - accuracy: 0.6578 - val_loss: 0.8868 - val_accuracy: 0.6702
# Epoch 20/100
# 12/12 [==============================] - 0s 6ms/step - loss: 0.8334 - accuracy: 0.6711 - val_loss: 0.9033 - val_accuracy: 0.6596
# Epoch 21/100
# 12/12 [==============================] - 0s 6ms/step - loss: 0.8324 - accuracy: 0.6872 - val_loss: 0.8763 - val_accuracy: 0.6702
# Epoch 22/100
# 12/12 [==============================] - 0s 6ms/step - loss: 0.8428 - accuracy: 0.6765 - val_loss: 0.8725 - val_accuracy: 0.6596
# Epoch 23/100
# 12/12 [==============================] - 0s 6ms/step - loss: 0.8569 - accuracy: 0.6711 - val_loss: 0.8707 - val_accuracy: 0.6596
# Epoch 24/100
# 12/12 [==============================] - 0s 5ms/step - loss: 0.8007 - accuracy: 0.7032 - val_loss: 0.8658 - val_accuracy: 0.6702
# Epoch 25/100
# 12/12 [==============================] - 0s 6ms/step - loss: 0.7922 - accuracy: 0.6979 - val_loss: 0.8547 - val_accuracy: 0.6596
# Epoch 26/100
# 12/12 [==============================] - 0s 6ms/step - loss: 0.8275 - accuracy: 0.6818 - val_loss: 0.8499 - val_accuracy: 0.6596
# Epoch 27/100
# 12/12 [==============================] - 0s 6ms/step - loss: 0.7854 - accuracy: 0.6765 - val_loss: 0.8454 - val_accuracy: 0.6596
# Epoch 28/100
# 12/12 [==============================] - 0s 6ms/step - loss: 0.7895 - accuracy: 0.6818 - val_loss: 0.8362 - val_accuracy: 0.6596
# Epoch 29/100
# 12/12 [==============================] - 0s 5ms/step - loss: 0.8130 - accuracy: 0.6898 - val_loss: 0.8468 - val_accuracy: 0.6596
# Epoch 30/100
# 12/12 [==============================] - 0s 6ms/step - loss: 0.7858 - accuracy: 0.6765 - val_loss: 0.8607 - val_accuracy: 0.6702
# Epoch 31/100
# 12/12 [==============================] - 0s 5ms/step - loss: 0.8114 - accuracy: 0.6925 - val_loss: 0.8663 - val_accuracy: 0.6596
# Epoch 32/100
# 12/12 [==============================] - 0s 6ms/step - loss: 0.7694 - accuracy: 0.6979 - val_loss: 0.8677 - val_accuracy: 0.6596
# Epoch 33/100
# 12/12 [==============================] - 0s 6ms/step - loss: 0.7856 - accuracy: 0.6979 - val_loss: 0.8635 - val_accuracy: 0.6596
# Epoch 34/100
# 12/12 [==============================] - 0s 6ms/step - loss: 0.7378 - accuracy: 0.7086 - val_loss: 0.8669 - val_accuracy: 0.6489
# Epoch 35/100
# 12/12 [==============================] - 0s 5ms/step - loss: 0.7476 - accuracy: 0.7032 - val_loss: 0.8798 - val_accuracy: 0.6489
# Epoch 36/100
# 12/12 [==============================] - 0s 5ms/step - loss: 0.7731 - accuracy: 0.6845 - val_loss: 0.8639 - val_accuracy: 0.6489
# Epoch 37/100
# 12/12 [==============================] - 0s 6ms/step - loss: 0.7704 - accuracy: 0.6791 - val_loss: 0.8694 - val_accuracy: 0.6383
# Epoch 38/100
# 12/12 [==============================] - 0s 5ms/step - loss: 0.7731 - accuracy: 0.7139 - val_loss: 0.8789 - val_accuracy: 0.6489
# Epoch 39/100
# 12/12 [==============================] - 0s 6ms/step - loss: 0.7482 - accuracy: 0.7005 - val_loss: 0.8718 - val_accuracy: 0.6489
# Epoch 40/100
# 12/12 [==============================] - 0s 5ms/step - loss: 0.7475 - accuracy: 0.6925 - val_loss: 0.8554 - val_accuracy: 0.6489
# Epoch 41/100
# 12/12 [==============================] - 0s 5ms/step - loss: 0.7487 - accuracy: 0.6845 - val_loss: 0.8642 - val_accuracy: 0.6596
# Epoch 42/100
# 12/12 [==============================] - 0s 6ms/step - loss: 0.7383 - accuracy: 0.6818 - val_loss: 0.8811 - val_accuracy: 0.6596
# Epoch 43/100
# 12/12 [==============================] - 0s 5ms/step - loss: 0.7220 - accuracy: 0.6925 - val_loss: 0.8863 - val_accuracy: 0.6596
# Epoch 44/100
# 12/12 [==============================] - 0s 5ms/step - loss: 0.7751 - accuracy: 0.6925 - val_loss: 0.8888 - val_accuracy: 0.6489
# Epoch 45/100
# 12/12 [==============================] - 0s 5ms/step - loss: 0.7235 - accuracy: 0.7219 - val_loss: 0.8844 - val_accuracy: 0.6596
# Epoch 46/100
# 12/12 [==============================] - 0s 5ms/step - loss: 0.7471 - accuracy: 0.6872 - val_loss: 0.8914 - val_accuracy: 0.6596
# Epoch 47/100
# 12/12 [==============================] - 0s 6ms/step - loss: 0.7066 - accuracy: 0.7086 - val_loss: 0.8837 - val_accuracy: 0.6702
# Epoch 48/100
# 12/12 [==============================] - 0s 5ms/step - loss: 0.7240 - accuracy: 0.6979 - val_loss: 0.8824 - val_accuracy: 0.6702
# Epoch 49/100
# 12/12 [==============================] - 0s 6ms/step - loss: 0.6798 - accuracy: 0.7166 - val_loss: 0.8801 - val_accuracy: 0.6489
# Epoch 50/100
# 12/12 [==============================] - 0s 6ms/step - loss: 0.7570 - accuracy: 0.6952 - val_loss: 0.8803 - val_accuracy: 0.6702
# Epoch 51/100
# 12/12 [==============================] - 0s 8ms/step - loss: 0.7593 - accuracy: 0.6898 - val_loss: 0.8837 - val_accuracy: 0.6809
# Epoch 52/100
# 12/12 [==============================] - 0s 6ms/step - loss: 0.7042 - accuracy: 0.6791 - val_loss: 0.8730 - val_accuracy: 0.6702
# Epoch 53/100
# 12/12 [==============================] - 0s 5ms/step - loss: 0.7198 - accuracy: 0.7219 - val_loss: 0.8763 - val_accuracy: 0.6702
# Epoch 54/100
# 12/12 [==============================] - 0s 6ms/step - loss: 0.7304 - accuracy: 0.7032 - val_loss: 0.9040 - val_accuracy: 0.6702
# Epoch 55/100
# 12/12 [==============================] - 0s 5ms/step - loss: 0.7100 - accuracy: 0.7032 - val_loss: 0.8794 - val_accuracy: 0.6702
# Epoch 56/100
# 12/12 [==============================] - 0s 5ms/step - loss: 0.6801 - accuracy: 0.7594 - val_loss: 0.8908 - val_accuracy: 0.6489
# Epoch 57/100
# 12/12 [==============================] - 0s 6ms/step - loss: 0.7228 - accuracy: 0.6952 - val_loss: 0.8864 - val_accuracy: 0.6809
# Epoch 58/100
# 12/12 [==============================] - 0s 5ms/step - loss: 0.6727 - accuracy: 0.7139 - val_loss: 0.9049 - val_accuracy: 0.6809
# Epoch 59/100
# 12/12 [==============================] - 0s 5ms/step - loss: 0.6893 - accuracy: 0.7086 - val_loss: 0.9014 - val_accuracy: 0.6809
# Epoch 60/100
# 12/12 [==============================] - 0s 5ms/step - loss: 0.6906 - accuracy: 0.7193 - val_loss: 0.8932 - val_accuracy: 0.6809
# Epoch 61/100
# 12/12 [==============================] - 0s 5ms/step - loss: 0.6805 - accuracy: 0.7005 - val_loss: 0.8845 - val_accuracy: 0.6915
# Epoch 62/100
# 12/12 [==============================] - 0s 5ms/step - loss: 0.7116 - accuracy: 0.6952 - val_loss: 0.8751 - val_accuracy: 0.6809
# Epoch 63/100
# 12/12 [==============================] - 0s 6ms/step - loss: 0.6588 - accuracy: 0.7326 - val_loss: 0.8893 - val_accuracy: 0.6596
# Epoch 64/100
# 12/12 [==============================] - 0s 5ms/step - loss: 0.7135 - accuracy: 0.7032 - val_loss: 0.8906 - val_accuracy: 0.6489
# Epoch 65/100
# 12/12 [==============================] - 0s 5ms/step - loss: 0.6819 - accuracy: 0.7005 - val_loss: 0.9042 - val_accuracy: 0.6809
# Epoch 66/100
# 12/12 [==============================] - 0s 6ms/step - loss: 0.7154 - accuracy: 0.7059 - val_loss: 0.9095 - val_accuracy: 0.6809
# Epoch 67/100
# 12/12 [==============================] - 0s 5ms/step - loss: 0.6871 - accuracy: 0.7166 - val_loss: 0.9004 - val_accuracy: 0.6809
# Epoch 68/100
# 12/12 [==============================] - 0s 6ms/step - loss: 0.6764 - accuracy: 0.7059 - val_loss: 0.8884 - val_accuracy: 0.6702
# Epoch 69/100
# 12/12 [==============================] - 0s 6ms/step - loss: 0.7023 - accuracy: 0.7059 - val_loss: 0.8752 - val_accuracy: 0.6383
# Epoch 70/100
# 12/12 [==============================] - 0s 6ms/step - loss: 0.7040 - accuracy: 0.7193 - val_loss: 0.8822 - val_accuracy: 0.6383
# Epoch 71/100
# 12/12 [==============================] - 0s 6ms/step - loss: 0.6917 - accuracy: 0.7273 - val_loss: 0.9061 - val_accuracy: 0.6915
# Epoch 72/100
# 12/12 [==============================] - 0s 6ms/step - loss: 0.6891 - accuracy: 0.7086 - val_loss: 0.8903 - val_accuracy: 0.6915
# Epoch 73/100
# 12/12 [==============================] - 0s 5ms/step - loss: 0.6644 - accuracy: 0.7219 - val_loss: 0.9144 - val_accuracy: 0.6383
# Epoch 74/100
# 12/12 [==============================] - 0s 5ms/step - loss: 0.7056 - accuracy: 0.7086 - val_loss: 0.9121 - val_accuracy: 0.6596
# Epoch 75/100
# 12/12 [==============================] - 0s 6ms/step - loss: 0.6767 - accuracy: 0.7326 - val_loss: 0.9108 - val_accuracy: 0.6383
# Epoch 76/100
# 12/12 [==============================] - 0s 7ms/step - loss: 0.6440 - accuracy: 0.7406 - val_loss: 0.9081 - val_accuracy: 0.6489
# Epoch 77/100
# 12/12 [==============================] - 0s 6ms/step - loss: 0.6742 - accuracy: 0.7246 - val_loss: 0.9150 - val_accuracy: 0.6702
# Epoch 78/100
# 12/12 [==============================] - 0s 6ms/step - loss: 0.6598 - accuracy: 0.7005 - val_loss: 0.9039 - val_accuracy: 0.6702
# Epoch 79/100
# 12/12 [==============================] - 0s 6ms/step - loss: 0.6718 - accuracy: 0.7112 - val_loss: 0.8787 - val_accuracy: 0.6702
# Epoch 80/100
# 12/12 [==============================] - 0s 6ms/step - loss: 0.6923 - accuracy: 0.7193 - val_loss: 0.8693 - val_accuracy: 0.6809
# Epoch 81/100
# 12/12 [==============================] - 0s 6ms/step - loss: 0.6743 - accuracy: 0.7166 - val_loss: 0.8831 - val_accuracy: 0.6489
# Epoch 82/100
# 12/12 [==============================] - 0s 6ms/step - loss: 0.6748 - accuracy: 0.7193 - val_loss: 0.9141 - val_accuracy: 0.6383
# Epoch 83/100
# 12/12 [==============================] - 0s 6ms/step - loss: 0.6468 - accuracy: 0.7353 - val_loss: 0.9366 - val_accuracy: 0.6383
# Epoch 84/100
# 12/12 [==============================] - 0s 6ms/step - loss: 0.6838 - accuracy: 0.7112 - val_loss: 0.9223 - val_accuracy: 0.6170
# Epoch 85/100
# 12/12 [==============================] - 0s 6ms/step - loss: 0.6741 - accuracy: 0.6925 - val_loss: 0.8933 - val_accuracy: 0.6277
# Epoch 86/100
# 12/12 [==============================] - 0s 6ms/step - loss: 0.6796 - accuracy: 0.7299 - val_loss: 0.8837 - val_accuracy: 0.6383
# Epoch 87/100
# 12/12 [==============================] - 0s 8ms/step - loss: 0.6686 - accuracy: 0.7166 - val_loss: 0.8840 - val_accuracy: 0.6383
# Epoch 88/100
# 12/12 [==============================] - 0s 6ms/step - loss: 0.6861 - accuracy: 0.7059 - val_loss: 0.8848 - val_accuracy: 0.6489
# Epoch 89/100
# 12/12 [==============================] - 0s 7ms/step - loss: 0.6522 - accuracy: 0.7246 - val_loss: 0.9150 - val_accuracy: 0.6596
# Epoch 90/100
# 12/12 [==============================] - 0s 6ms/step - loss: 0.6770 - accuracy: 0.7219 - val_loss: 0.9236 - val_accuracy: 0.6702
# Epoch 91/100
# 12/12 [==============================] - 0s 6ms/step - loss: 0.6449 - accuracy: 0.7380 - val_loss: 0.9289 - val_accuracy: 0.6596
# Epoch 92/100
# 12/12 [==============================] - 0s 6ms/step - loss: 0.6615 - accuracy: 0.7273 - val_loss: 0.9175 - val_accuracy: 0.6702
# Epoch 93/100
# 12/12 [==============================] - 0s 6ms/step - loss: 0.6841 - accuracy: 0.7353 - val_loss: 0.9134 - val_accuracy: 0.6702
# Epoch 94/100
# 12/12 [==============================] - 0s 6ms/step - loss: 0.6770 - accuracy: 0.7273 - val_loss: 0.9026 - val_accuracy: 0.6809
# Epoch 95/100
# 12/12 [==============================] - 0s 6ms/step - loss: 0.6560 - accuracy: 0.7139 - val_loss: 0.8962 - val_accuracy: 0.6915
# Epoch 96/100
# 12/12 [==============================] - 0s 6ms/step - loss: 0.6366 - accuracy: 0.7353 - val_loss: 0.8972 - val_accuracy: 0.6915
# Epoch 97/100
# 12/12 [==============================] - 0s 6ms/step - loss: 0.6855 - accuracy: 0.7326 - val_loss: 0.9022 - val_accuracy: 0.6596
# Epoch 98/100
# 12/12 [==============================] - 0s 6ms/step - loss: 0.6693 - accuracy: 0.7299 - val_loss: 0.9162 - val_accuracy: 0.6277
# Epoch 99/100
# 12/12 [==============================] - 0s 6ms/step - loss: 0.6506 - accuracy: 0.7433 - val_loss: 0.9360 - val_accuracy: 0.6383
# Epoch 100/100
# 12/12 [==============================] - 0s 6ms/step - loss: 0.6699 - accuracy: 0.7299 - val_loss: 0.9291 - val_accuracy: 0.6277

# %%
import matplotlib.pyplot as plt

plt.plot(history.history['accuracy'], label='train acc')
plt.plot(history.history['val_accuracy'], label='val acc')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.title('Model Accuracy')
plt.legend()
plt.grid(True)
plt.show()

# %%
from sklearn.metrics import classification_report

# Predict class probabilities
y_pred_probs = model.predict(x_test)

# Convert to class labels
y_pred_classes = np.argmax(y_pred_probs, axis=1)
y_true_classes = np.argmax(y_test, axis=1)

# Print classification report
print(classification_report(y_true_classes, y_pred_classes, target_names=label_encoder.classes_))
# Out:
# 4/4 [==============================] - 0s 2ms/step
#               precision    recall  f1-score   support
#
#     artifact       1.00      0.75      0.86         8
#     extrahls       0.50      0.25      0.33         4
#   extrastole       0.00      0.00      0.00         9
#       murmur       0.62      0.62      0.62        26
#       normal       0.76      0.90      0.82        70
#
#     accuracy                           0.74       117
#    macro avg       0.57      0.50      0.53       117
# weighted avg       0.68      0.74      0.70       117

# %%
# import joblib

# model.save('model/ann_model.h5')
# joblib.dump(label_encoder, 'model/ann_label_encoder.pkl')
# Out:
# ['model/lstm_label_encoder.pkl']

# %% [markdown]
# ## Testing

# %%
def preprocess_and_extract_features_from_file(file_path, target_duration=6):
    try:
        signal, sr = librosa.load(file_path, sr=None)
    except Exception as e:
        print(f"Error loading audio file: {e}")
        return None

    # Normalize
    normalized_signal = normalize_audio(signal)

    # Pad or clip
    target_samples = int(target_duration * sr)
    processed_signal = clip_or_pad(normalized_signal, target_samples)

    # Band-pass filter
    filtered_signal = band_pass_filter(processed_signal, lowcut=100, highcut=1500, fs=sr)

    # Extract features
    features = extract_features(filtered_signal, sr)

    # Flatten MFCC and Chroma
    mfcc_flat = features['mfcc_mean']
    chroma_flat = features['chroma_mean']

    # Combine features into a single vector
    feature_vector = np.hstack((
        np.array([
            features['mean_interval'], features['sdnn'], features['rmssd'],
            features['peak_freq'], features['energy'],
            features['zero_crossing_rate'], features['spectral_centroid_mean'],
            features['spectral_bandwidth_mean'], features['rms_mean']
        ]),
        mfcc_flat,
        chroma_flat
    ))

    return feature_vector.reshape(1, -1)  # Reshape for model prediction

# %%
def predict_heartbeat_class(file_path):
    features = preprocess_and_extract_features_from_file(file_path)
    
    if features is None:
        print("Feature extraction failed.")
        return

    # Predict
    prediction_probs = model.predict(features)
    predicted_class_index = np.argmax(prediction_probs)
    predicted_class_label = label_encoder.inverse_transform([predicted_class_index])[0]
    
    print(f"Predicted class: {predicted_class_label}")
    print(f"Class probabilities: {prediction_probs}")

# %%
test_file_path = 'Heartbeat_Sound/artifact/artifact__201105051017.wav'  # Replace with actual path
predict_heartbeat_class(test_file_path)
# Out:
# 1/1 [==============================] - 0s 25ms/step
# Predicted class: artifact
# Class probabilities: [[9.3394721e-01 1.2212955e-02 5.3860235e-04 1.9176167e-02 3.4125105e-02]]
